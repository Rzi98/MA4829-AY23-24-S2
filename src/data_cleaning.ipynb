# %% [markdown]
# ##

# %%
import pandas as pd

df = pd.read_excel(io='../data/SURVEY RESULTS_2024.xlsx', sheet_name='Customer preference in car')

df.head(3)
# Out:
#   Which age group do you belong to? What is your gender?  \
# 0                             20-30                 Male
# 1                             20-30               Female
# 2                             20-30                 Male
#
#           Which category do you currently belong to?  \
# 0  Do not own a car, but planning to purchase in ...
# 1  Do not own a car, but planning to purchase in ...
# 2  Do not own a car, but planning to purchase in ...
#
#   Which of the following best describes you?  \
# 0                                     Single
# 1                                     Single
# 2                                     Single
#
#   Which of these factors are important to you when deciding which car to purchase?  \
# 0      Price;Functionality;Size;Customisable options
# 1  Price;Brand name;Aesthetics;Technological feat...
# 2      Aesthetics;Functionality;Customisable options
#
#   How likely are you to opt for customised vehicle if there were no extra charges?   \
# 0                                        Very likely
# 1                                             Likely
# 2                                        Very likely
#
#   Which of the following exterior components would you choose to customise (texture, layout, size, etc)?   \
# 0                                            Grilles
# 1             Wheels;Grilles;Headlights;Side mirrors
# 2             Wheels;Grilles;Headlights;Side mirrors
#
#   Which of the following interior components would you choose to customise (texture, layout, size, etc)?   \
# 0                                 Centre compartment
# 1                                 Centre compartment
# 2                           Steering wheel;Dashboard
#
#   How much are you willing to spend on car customisation if surcharges are applicable?  \
# 0                                            100-500
# 1                                          under 500
# 2                                           500-1000
#
#   Are you interested in designing your own components to personalise your car?   \
# 0                        Only with professional help
# 1                        Only with professional help
# 2                                                Yes
#
#   How much are you willing to pay for the personalised design?   \
# 0                                           500-1000
# 1                                          under 500
# 2                                           500-1000
#
#   Do you have any 3D design experience that would help with the design process? (e.g. AutoCAD, SolidWorks, Blender, etc)  \
# 0     No, I would need a designer to model my sketch
# 1     No, I would need a designer to model my sketch
# 2                        Yes, I can design on my own
#
#   Please give us any design ideas to make the car uniquely Singaporean.
# 0                                                NaN
# 1          wheels that look like the singapore flyer
# 2                                                NaN

# %% [markdown]
# ### **Renaming columns to shorten names** ###

# %%
df.rename(columns={
    'Which age group do you belong to?': 'Age group',
    'What is your gender?': 'Gender',
    'Which category do you currently belong to?': 'Category',
    'Which of the following best describes you?': 'Marital status',
    'Which of these factors are important to you when deciding which car to purchase?': 'Deciding factors to buy car',
    'How likely are you to opt for customised vehicle if there were no extra charges? ': 'Likelihood of customised vehicle if FOC',
    'Which of the following exterior components would you choose to customise (texture, layout, size, etc)? ': 'Exterior components to customise',
    'Which of the following interior components would you choose to customise (texture, layout, size, etc)? ': 'Interior components to customise',
    'How much are you willing to spend on car customisation if surcharges are applicable?': 'Customisation Budget',
    'How much are you willing to pay for the personalised design? ': 'Personalisation Budget',
    'Are you interested in designing your own components to personalise your car? ': 'Interest in personalising car',
    'Do you have any 3D design experience that would help with the design process? (e.g. AutoCAD, SolidWorks, Blender, etc)': 'Any cadding experience',
    'Please give us any design ideas to make the car uniquely Singaporean.': 'Singaporean design idea feedback',
}, inplace=True)

df.head(3)
# Out:
#   Age group  Gender                                           Category  \
# 0     20-30    Male  Do not own a car, but planning to purchase in ...
# 1     20-30  Female  Do not own a car, but planning to purchase in ...
# 2     20-30    Male  Do not own a car, but planning to purchase in ...
#
#   Marital status                        Deciding factors to buy car  \
# 0         Single      Price;Functionality;Size;Customisable options
# 1         Single  Price;Brand name;Aesthetics;Technological feat...
# 2         Single      Aesthetics;Functionality;Customisable options
#
#   Likelihood of customised vehicle if FOC  \
# 0                             Very likely
# 1                                  Likely
# 2                             Very likely
#
#          Exterior components to customise Interior components to customise  \
# 0                                 Grilles               Centre compartment
# 1  Wheels;Grilles;Headlights;Side mirrors               Centre compartment
# 2  Wheels;Grilles;Headlights;Side mirrors         Steering wheel;Dashboard
#
#   Customisation Budget Interest in personalising car Personalisation Budget  \
# 0              100-500   Only with professional help               500-1000
# 1            under 500   Only with professional help              under 500
# 2             500-1000                           Yes               500-1000
#
#                            Any cadding experience  \
# 0  No, I would need a designer to model my sketch
# 1  No, I would need a designer to model my sketch
# 2                     Yes, I can design on my own
#
#             Singaporean design idea feedback
# 0                                        NaN
# 1  wheels that look like the singapore flyer
# 2                                        NaN

# %% [markdown]
# ### **Giving Unique Customer ID to each row** ###
#
# - In a real world database, each customer will be given a unique ID for tracking & analysis
# - But in this case, since it is a survey, it is not really important to know who the customer is but I will just add it

# %%
import uuid

df['Respondent ID'] = [str(uuid.uuid4()) for _ in range(len(df))]
df = df[['Respondent ID'] + [col for col in df.columns if col != 'Respondent ID']]
df.head()
# Out:
#                           Respondent ID Age group  Gender  \
# 0  bc57816c-afed-4fab-b853-29e1a685b3c0     20-30    Male
# 1  62acce28-3d37-4009-8278-f2301c518349     20-30  Female
# 2  738ce5ff-29b2-49d5-ab65-4499e4ca9c72     20-30    Male
# 3  59ae797a-51a5-4b2d-9f14-5fc60ed47c30     20-30  Female
# 4  341e6b58-cbb3-4878-b30f-4df595acebc2     20-30    Male
#
#                                             Category Marital status  \
# 0  Do not own a car, but planning to purchase in ...         Single
# 1  Do not own a car, but planning to purchase in ...         Single
# 2  Do not own a car, but planning to purchase in ...         Single
# 3  Do not own a car, but planning to purchase in ...         Single
# 4  Do not own a car, but planning to purchase in ...         Single
#
#                          Deciding factors to buy car  \
# 0      Price;Functionality;Size;Customisable options
# 1  Price;Brand name;Aesthetics;Technological feat...
# 2      Aesthetics;Functionality;Customisable options
# 3  Price;Brand name;Aesthetics;Technological feat...
# 4  Price;Brand name;Aesthetics;Technological feat...
#
#   Likelihood of customised vehicle if FOC  \
# 0                             Very likely
# 1                                  Likely
# 2                             Very likely
# 3                             Very likely
# 4                             Very likely
#
#                  Exterior components to customise  \
# 0                                         Grilles
# 1          Wheels;Grilles;Headlights;Side mirrors
# 2          Wheels;Grilles;Headlights;Side mirrors
# 3  Wheels;Grilles;Headlights;Side mirrors;Bumpers
# 4               Wheels;Grilles;Headlights;Bumpers
#
#                     Interior components to customise Customisation Budget  \
# 0                                 Centre compartment              100-500
# 1                                 Centre compartment            under 500
# 2                           Steering wheel;Dashboard             500-1000
# 3  Steering wheel;Centre compartment;Door handles...            under 500
# 4                  Steering wheel;Centre compartment            over 1000
#
#   Interest in personalising car Personalisation Budget  \
# 0   Only with professional help               500-1000
# 1   Only with professional help              under 500
# 2                           Yes               500-1000
# 3                           Yes              under 500
# 4   Only with professional help              over 1000
#
#                            Any cadding experience  \
# 0  No, I would need a designer to model my sketch
# 1  No, I would need a designer to model my sketch
# 2                     Yes, I can design on my own
# 3  No, I would need a designer to model my sketch
# 4  No, I would need a designer to model my sketch
#
#             Singaporean design idea feedback
# 0                                        NaN
# 1  wheels that look like the singapore flyer
# 2                                        NaN
# 3                                        NaN
# 4          Sg flag/ colour related car paint

# %%
df.iloc[:, 1:].describe()
# Out:
#        Age group Gender                                           Category  \
# count         50     50                                                 50
# unique         4      3                                                  3
# top        20-30   Male  Do not own a car, but planning to purchase in ...
# freq          41     32                                                 36
#
#        Marital status                        Deciding factors to buy car  \
# count              50                                                 49
# unique              3                                                 37
# top            Single  Price;Brand name;Aesthetics;Technological feat...
# freq               38                                                  5
#
#        Likelihood of customised vehicle if FOC  \
# count                                       50
# unique                                       3
# top                                Very likely
# freq                                        37
#
#        Exterior components to customise Interior components to customise  \
# count                                49                               50
# unique                               23                               16
# top                              Wheels                        Dashboard
# freq                                  8                               11
#
#        Customisation Budget Interest in personalising car  \
# count                    50                            50
# unique                    5                             3
# top                500-1000   Only with professional help
# freq                     19                            26
#
#        Personalisation Budget                          Any cadding experience  \
# count                      50                                              50
# unique                      4                                               2
# top                  500-1000  No, I would need a designer to model my sketch
# freq                       21                                              33
#
#                  Singaporean design idea feedback
# count                                          17
# unique                                         17
# top     wheels that look like the singapore flyer
# freq                                            1

# %%
df.to_csv('../data/cleaned_data.csv', index=False)
df.to_excel('../data/cleaned_data.xlsx', index=False)

# %%
df.head()
# Out:
#                           Respondent ID Age group  Gender  \
# 0  3692d111-b5ca-47cb-9266-9886a1c2202a     20-30    Male
# 1  bf2da5c6-19f4-4a9b-aef6-bf8203c1f387     20-30  Female
# 2  ec1510d8-329f-48a4-be17-a1c87b51b5ed     20-30    Male
# 3  9e1f5674-6e87-47df-9c5e-c0b6c6005108     20-30  Female
# 4  55633410-16cf-43eb-85cf-1bac1fb966f7     20-30    Male
#
#                                             Category Marital status  \
# 0  Do not own a car, but planning to purchase in ...         Single
# 1  Do not own a car, but planning to purchase in ...         Single
# 2  Do not own a car, but planning to purchase in ...         Single
# 3  Do not own a car, but planning to purchase in ...         Single
# 4  Do not own a car, but planning to purchase in ...         Single
#
#                          Deciding factors to buy car  \
# 0      Price;Functionality;Size;Customisable options
# 1  Price;Brand name;Aesthetics;Technological feat...
# 2      Aesthetics;Functionality;Customisable options
# 3  Price;Brand name;Aesthetics;Technological feat...
# 4  Price;Brand name;Aesthetics;Technological feat...
#
#   Likelihood of customised vehicle if FOC  \
# 0                             Very likely
# 1                                  Likely
# 2                             Very likely
# 3                             Very likely
# 4                             Very likely
#
#                  Exterior components to customise  \
# 0                                         Grilles
# 1          Wheels;Grilles;Headlights;Side mirrors
# 2          Wheels;Grilles;Headlights;Side mirrors
# 3  Wheels;Grilles;Headlights;Side mirrors;Bumpers
# 4               Wheels;Grilles;Headlights;Bumpers
#
#                     Interior components to customise Customisation Budget  \
# 0                                 Centre compartment              100-500
# 1                                 Centre compartment            under 500
# 2                           Steering wheel;Dashboard             500-1000
# 3  Steering wheel;Centre compartment;Door handles...            under 500
# 4                  Steering wheel;Centre compartment            over 1000
#
#   Interest in personalising car Personalisation Budget  \
# 0   Only with professional help               500-1000
# 1   Only with professional help              under 500
# 2                           Yes               500-1000
# 3                           Yes              under 500
# 4   Only with professional help              over 1000
#
#                            Any cadding experience  \
# 0  No, I would need a designer to model my sketch
# 1  No, I would need a designer to model my sketch
# 2                     Yes, I can design on my own
# 3  No, I would need a designer to model my sketch
# 4  No, I would need a designer to model my sketch
#
#             Singaporean design idea feedback
# 0                                        NaN
# 1  wheels that look like the singapore flyer
# 2                                        NaN
# 3                                        NaN
# 4          Sg flag/ colour related car paint
